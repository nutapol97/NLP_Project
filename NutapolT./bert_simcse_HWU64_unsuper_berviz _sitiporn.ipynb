# %%
import os
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import RobertaConfig, RobertaModel, RobertaTokenizer, RobertaForSequenceClassification
from transformers import AdamW
import random
from IPython.display import clear_output
import matplotlib.pyplot as plt
from collections import OrderedDict
from scipy.spatial.distance import cosine
from sim_utils import load_examples, Inputexample, CustomTextDataset, freeze_layers, train, test
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer, AutoConfig, AutoModel, AutoTokenizer
#comment this if you are not using puffer
os.environ['http_proxy'] = 'http://192.41.170.23:3128'
os.environ['https_proxy'] = 'http://192.41.170.23:3128'

# %%
N = 5
data = []
labels = []

train_samples = []
train_labels = []

valid_samples = []
valid_labels = []

test_samples = []
test_labels = []

embed_dim = 768
batch_size = 16
lr=2e-3  # you can adjust 
temp = 0.3  # you can adjust 
lamda = 0.01  # you can adjust  
skip_time = 0 # the number of time that yi not equal to yj in supervised contrastive loss equation 
data_name = '64'
model_name = 'sup-simcse-bert'
shot_name = 'train_5'
exp_name = f'{model_name}_lr={lr}_t={temp}_{data_name}_{shot_name}'
device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### The Aim of these training is to fine tuning on few shot setting on text classification task

# %% [markdown]
# Path example of train, validation and test

# %%
path_5shot = f'./HWU64/train_5/'
valid_path = f'./HWU64/valid/'
test_path = f'./HWU64/test/'

# %% [raw]
# path_5shot = f'../../../../Thesis/CLINC150/train_5/'
# valid_path = f'../../../../Thesis/CLINC150/valid/'
# test_path = f'../../../../Thesis/CLINC150//test/'

# %%
# Download data fewshot 
# https://downgit.github.io/#/home?url=https:%2F%2Fgithub.com%2Fjianguoz%2FFew-Shot-Intent-Detection%2Ftree%2Fmain%2FDatasets%2FHWU64

# load data
train_samples = load_examples(path_5shot)
valid_samples = load_examples(valid_path)
test_samples = load_examples(test_path)


print("===== small train set ====")

for i in range(len(train_samples)):
    data.append(train_samples[i].text)
    labels.append(train_samples[i].label)


train_data = CustomTextDataset(labels,data,batch_size=batch_size,repeated_label=False)
train_loader = DataLoader(train_data,batch_size=batch_size,shuffle=True)



print("===== validation set ====")

data = []
labels = []

for i in range(len(valid_samples)):
    data.append(valid_samples[i].text)
    labels.append(valid_samples[i].label)

valid_data = CustomTextDataset(labels,data,batch_size=batch_size,repeated_label=False)
valid_loader = DataLoader(valid_data,batch_size=batch_size,shuffle=True)



print("===== test set ====")

data = []
labels = []
    
for i in range(len(test_samples)):
    data.append(test_samples[i].text)
    labels.append(test_samples[i].label)

test_data = CustomTextDataset(labels,data,batch_size=batch_size,repeated_label=False)
test_loader = DataLoader(test_data,batch_size=batch_size,shuffle=True)



# got the number of unique classes from dataset
num_class = len(np.unique(np.array(labels)))
print(" the number of class : ", num_class)

# get text label of uniqure classes
unique_label = np.unique(np.array(labels))

# map text label to index classes
label_maps = {unique_label[i]: i for i in range(len(unique_label))}
# Out:
# ===== small train set ====
# Train on Cross Entropy loss
# len of dataset : 320
# ===== validation set ====
# Train on Cross Entropy loss
# len of dataset : 1076
# ===== test set ====
# Train on Cross Entropy loss
# len of dataset : 1076
#  the number of class :  64

# %%
tokenizer = AutoTokenizer.from_pretrained("princeton-nlp/unsup-simcse-bert-base-uncased")
config = AutoConfig.from_pretrained("princeton-nlp/unsup-simcse-bert-base-uncased",output_attentions=True)
config.num_labels = num_class
simcse = AutoModelForSequenceClassification.from_pretrained("princeton-nlp/unsup-simcse-bert-base-uncased",config=config)
simcse = freeze_layers(simcse,freeze_layers_count=12)
# Out:
# Downloading:   0%|          | 0.00/252 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/697 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at princeton-nlp/unsup-simcse-bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# classifier.weight
# classifier.bias

# %%
with torch.no_grad():
    
    for new_name, new_param in simcse.named_parameters():

        new_keys = new_name.split(".")

        for old_name, old_param in simcse.named_parameters():

            old_keys = old_name.split(".")

            if new_keys[1:] == old_keys:
                # print("-----------------------")
                # print(new_keys[1:])
                # print(old_keys)
                # print("-----------------------")
                # if new_param.shape == old_param.shape
                # feed old weight to new network
                model.state_dict()[new_name].data.copy_(old_param)
                
                assert torch.all(model.state_dict()[new_name] == simcse.state_dict()[old_name])
                                
print("Done with feed old weight to new architecure")
# Out:
# Done with feed old weight to new architecure

# %%
model = freeze_layers(simcse,freeze_layers_count=12)
# Out:
# classifier.weight
# classifier.bias

# %%
optimizer= AdamW(model.parameters(), lr=lr)
model = model.to(device)

# %%
# !nvidia-smi
# Out:
# Tue Apr 12 13:43:59 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:84:00.0 Off |                  N/A |
# | 50%   81C    P2   237W / 250W |  10984MiB / 11264MiB |     62%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  On   | 00000000:85:00.0 Off |                  N/A |
# | 22%   34C    P8     2W / 250W |   6792MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA GeForce ...  On   | 00000000:88:00.0 Off |                  N/A |
# | 22%   30C    P8     6W / 250W |      3MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA GeForce ...  On   | 00000000:89:00.0 Off |                  N/A |
# | 22%   38C    P2    52W / 250W |   5498MiB / 11264MiB |      6%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     16510      C                                   10981MiB |
# |    1   N/A  N/A     20209      C                                    6789MiB |
# |    3   N/A  N/A     20379      C                                    2221MiB |
# |    3   N/A  N/A     23430      C                                    1639MiB |
# |    3   N/A  N/A     23499      C                                    1635MiB |
# +-----------------------------------------------------------------------------+

# %%
train_log, valid_log = train(exp_name,model,device,label_maps,optimizer,train_loader,valid_loader,train_data,valid_data,tokenizer,epochs=30)
# Out:
# ======  Epoch 1 ======
#  Training Loss: 0.25016173273324965, 		 Training acc: 0.11874999850988388
# train correct :  tensor(38, device='cuda:3')
# train total : 320
#  Validation Loss: 0.2240330685470184, 		 Validation acc: 0.410780668258667
# valid correct :  tensor(442, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(inf--->0.224033) 	 Saving The Model
# ======  Epoch 2 ======
#  Training Loss: 0.18905167579650878, 		 Training acc: 0.690625011920929
# train correct :  tensor(221, device='cuda:3')
# train total : 320
#  Validation Loss: 0.18526395568174056, 		 Validation acc: 0.5650557279586792
# valid correct :  tensor(608, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.224033--->0.185264) 	 Saving The Model
# ======  Epoch 3 ======
#  Training Loss: 0.14284635037183763, 		 Training acc: 0.859375
# train correct :  tensor(275, device='cuda:3')
# train total : 320
#  Validation Loss: 0.1550617912666505, 		 Validation acc: 0.6087360382080078
# valid correct :  tensor(655, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.185264--->0.155062) 	 Saving The Model
# ======  Epoch 4 ======
#  Training Loss: 0.10692712254822254, 		 Training acc: 0.9312500357627869
# train correct :  tensor(298, device='cuda:3')
# train total : 320
#  Validation Loss: 0.13426573480372092, 		 Validation acc: 0.6384758353233337
# valid correct :  tensor(687, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.155062--->0.134266) 	 Saving The Model
# ======  Epoch 5 ======
#  Training Loss: 0.08098414205014706, 		 Training acc: 0.940625011920929
# train correct :  tensor(301, device='cuda:3')
# train total : 320
#  Validation Loss: 0.11941998665217574, 		 Validation acc: 0.6449813842773438
# valid correct :  tensor(694, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.134266--->0.119420) 	 Saving The Model
# ======  Epoch 6 ======
#  Training Loss: 0.062386182509362696, 		 Training acc: 0.9625000357627869
# train correct :  tensor(308, device='cuda:3')
# train total : 320
#  Validation Loss: 0.10920520918963124, 		 Validation acc: 0.6589218974113464
# valid correct :  tensor(709, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.119420--->0.109205) 	 Saving The Model
# ======  Epoch 7 ======
#  Training Loss: 0.04999451842159033, 		 Training acc: 0.96875
# train correct :  tensor(310, device='cuda:3')
# train total : 320
#  Validation Loss: 0.10075285476822836, 		 Validation acc: 0.6691449880599976
# valid correct :  tensor(720, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.109205--->0.100753) 	 Saving The Model
# ======  Epoch 8 ======
#  Training Loss: 0.04019213244318962, 		 Training acc: 0.984375
# train correct :  tensor(315, device='cuda:3')
# train total : 320
#  Validation Loss: 0.09600750420616462, 		 Validation acc: 0.6710036993026733
# valid correct :  tensor(722, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.100753--->0.096008) 	 Saving The Model
# ======  Epoch 9 ======
#  Training Loss: 0.03291192492470145, 		 Training acc: 0.981249988079071
# train correct :  tensor(314, device='cuda:3')
# train total : 320
#  Validation Loss: 0.09206547413616818, 		 Validation acc: 0.6728624701499939
# valid correct :  tensor(724, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.096008--->0.092065) 	 Saving The Model
# ======  Epoch 10 ======
#  Training Loss: 0.027617208566516636, 		 Training acc: 0.9937500357627869
# train correct :  tensor(318, device='cuda:3')
# train total : 320
#  Validation Loss: 0.08818328347347926, 		 Validation acc: 0.6775093078613281
# valid correct :  tensor(729, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.092065--->0.088183) 	 Saving The Model
# ======  Epoch 11 ======
#  Training Loss: 0.024078702554106712, 		 Training acc: 0.9937500357627869
# train correct :  tensor(318, device='cuda:3')
# train total : 320
#  Validation Loss: 0.08667354462979894, 		 Validation acc: 0.6737918257713318
# valid correct :  tensor(725, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.088183--->0.086674) 	 Saving The Model
# ======  Epoch 12 ======
#  Training Loss: 0.020640236558392644, 		 Training acc: 0.987500011920929
# train correct :  tensor(316, device='cuda:3')
# train total : 320
#  Validation Loss: 0.08506701299470597, 		 Validation acc: 0.6756505370140076
# valid correct :  tensor(727, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.086674--->0.085067) 	 Saving The Model
# ======  Epoch 13 ======
#  Training Loss: 0.017937460774555804, 		 Training acc: 0.987500011920929
# train correct :  tensor(316, device='cuda:3')
# train total : 320
#  Validation Loss: 0.08373476088490185, 		 Validation acc: 0.6728624701499939
# valid correct :  tensor(724, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.085067--->0.083735) 	 Saving The Model
# ======  Epoch 14 ======
#  Training Loss: 0.016126517252996565, 		 Training acc: 0.9937500357627869
# train correct :  tensor(318, device='cuda:3')
# train total : 320
#  Validation Loss: 0.08230464271231655, 		 Validation acc: 0.6802973747253418
# valid correct :  tensor(732, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.083735--->0.082305) 	 Saving The Model
# ======  Epoch 15 ======
#  Training Loss: 0.014373947540298105, 		 Training acc: 0.9937500357627869
# train correct :  tensor(318, device='cuda:3')
# train total : 320
#  Validation Loss: 0.08153291905236511, 		 Validation acc: 0.678438663482666
# valid correct :  tensor(730, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.082305--->0.081533) 	 Saving The Model
# ======  Epoch 16 ======
#  Training Loss: 0.012463711248710752, 		 Training acc: 1.0
# train correct :  tensor(320, device='cuda:3')
# train total : 320
#  Validation Loss: 0.0791525610317528, 		 Validation acc: 0.6793680191040039
# valid correct :  tensor(731, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.081533--->0.079153) 	 Saving The Model
# ======  Epoch 17 ======
#  Training Loss: 0.0112928694114089, 		 Training acc: 1.0
# train correct :  tensor(320, device='cuda:3')
# train total : 320
#  Validation Loss: 0.07909971575311568, 		 Validation acc: 0.6821561455726624
# valid correct :  tensor(734, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.079153--->0.079100) 	 Saving The Model
# ======  Epoch 18 ======
#  Training Loss: 0.011329654557630419, 		 Training acc: 0.9937500357627869
# train correct :  tensor(318, device='cuda:3')
# train total : 320
#  Validation Loss: 0.07762918300705107, 		 Validation acc: 0.6756505370140076
# valid correct :  tensor(727, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.079100--->0.077629) 	 Saving The Model
# ======  Epoch 19 ======
#  Training Loss: 0.00961891794577241, 		 Training acc: 1.0
# train correct :  tensor(320, device='cuda:3')
# train total : 320
#  Validation Loss: 0.07790717333001275, 		 Validation acc: 0.678438663482666
# valid correct :  tensor(730, device='cuda:3')
# valid total : 1076
# ======  Epoch 20 ======
#  Training Loss: 0.008139583445154131, 		 Training acc: 1.0
# train correct :  tensor(320, device='cuda:3')
# train total : 320
#  Validation Loss: 0.07831874559027555, 		 Validation acc: 0.6775093078613281
# valid correct :  tensor(729, device='cuda:3')
# valid total : 1076
# ======  Epoch 21 ======
#  Training Loss: 0.008119254186749459, 		 Training acc: 1.0
# train correct :  tensor(320, device='cuda:3')
# train total : 320
#  Validation Loss: 0.07757064785988357, 		 Validation acc: 0.6793680191040039
# valid correct :  tensor(731, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.077629--->0.077571) 	 Saving The Model
# ======  Epoch 22 ======
#  Training Loss: 0.007595268893055618, 		 Training acc: 1.0
# train correct :  tensor(320, device='cuda:3')
# train total : 320
#  Validation Loss: 0.07633270749815335, 		 Validation acc: 0.6775093078613281
# valid correct :  tensor(729, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.077571--->0.076333) 	 Saving The Model
# ======  Epoch 23 ======
#  Training Loss: 0.007005956862121821, 		 Training acc: 0.996874988079071
# train correct :  tensor(319, device='cuda:3')
# train total : 320
#  Validation Loss: 0.07597313796388172, 		 Validation acc: 0.6821561455726624
# valid correct :  tensor(734, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.076333--->0.075973) 	 Saving The Model
# ======  Epoch 24 ======
#  Training Loss: 0.006833365035708994, 		 Training acc: 1.0
# train correct :  tensor(320, device='cuda:3')
# train total : 320
#  Validation Loss: 0.07595331451706727, 		 Validation acc: 0.6868029832839966
# valid correct :  tensor(739, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.075973--->0.075953) 	 Saving The Model
# ======  Epoch 25 ======
#  Training Loss: 0.006260324129834771, 		 Training acc: 1.0
# train correct :  tensor(320, device='cuda:3')
# train total : 320
#  Validation Loss: 0.07547611038314808, 		 Validation acc: 0.6830855011940002
# valid correct :  tensor(735, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.075953--->0.075476) 	 Saving The Model
# ======  Epoch 26 ======
#  Training Loss: 0.005589827976655215, 		 Training acc: 1.0
# train correct :  tensor(320, device='cuda:3')
# train total : 320
#  Validation Loss: 0.0758212326738471, 		 Validation acc: 0.6830855011940002
# valid correct :  tensor(735, device='cuda:3')
# valid total : 1076
# ======  Epoch 27 ======
#  Training Loss: 0.005941301106940955, 		 Training acc: 1.0
# train correct :  tensor(320, device='cuda:3')
# train total : 320
#  Validation Loss: 0.07567123284902715, 		 Validation acc: 0.6840148568153381
# valid correct :  tensor(736, device='cuda:3')
# valid total : 1076
# ======  Epoch 28 ======
#  Training Loss: 0.005006681336089969, 		 Training acc: 1.0
# train correct :  tensor(320, device='cuda:3')
# train total : 320
#  Validation Loss: 0.07560693043315278, 		 Validation acc: 0.684944212436676
# valid correct :  tensor(737, device='cuda:3')
# valid total : 1076
# ======  Epoch 29 ======
#  Training Loss: 0.00530920505989343, 		 Training acc: 1.0
# train correct :  tensor(320, device='cuda:3')
# train total : 320
#  Validation Loss: 0.07509257397908703, 		 Validation acc: 0.6793680191040039
# valid correct :  tensor(731, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.075476--->0.075093) 	 Saving The Model
# ======  Epoch 30 ======
#  Training Loss: 0.004626585799269378, 		 Training acc: 0.996874988079071
# train correct :  tensor(319, device='cuda:3')
# train total : 320
#  Validation Loss: 0.07641881216857513, 		 Validation acc: 0.6812267303466797
# valid correct :  tensor(733, device='cuda:3')
# valid total : 1076

# %%
fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Show by freezing 12 layers')
ax1.plot(torch.tensor(train_log[0] , device = 'cpu').tolist())
ax1.plot(torch.tensor(valid_log[0] , device = 'cpu').tolist())
ax1.legend(['train_acc','validation_acc'])
ax2.plot(torch.tensor(train_log[1] , device = 'cpu').tolist())
ax2.plot(torch.tensor(valid_log[1] , device = 'cpu').tolist())
ax2.legend(['train_loss','validation_loss'])

# %%
test_acc =test(model,device,label_maps,test_loader,len(test_data),tokenizer)
# Out:
# correct : 735
# total : 1076

# %%
print(f'Accuracy : {100 * test_acc} %')
# Out:
# Accuracy : 68.3085501858736 %

# %%
modelx = simcse

# %%
torch.save(simcse, "unsup64")

# %%
# Load model and retrieve attention weights
from transformers import BertTokenizer, BertForSequenceClassification
from bertviz import head_view, model_view
from transformers import BertTokenizer, BertModel
modelx = modelx.to('cpu')
model_version = 'bert-base-uncased'

#model = BertForSequenceClassification.from_pretrained(model_version, output_attentions=True)
#modelx = modelx.from_pretrained(model_version, output_attentions=True)
tokenizer = BertTokenizer.from_pretrained(model_version)
sentence_a = "would you please confirm the instruction."
sentence_b = "check and confirm my last question please."
inputs = tokenizer.encode_plus(sentence_a, return_tensors='pt')
input_ids = inputs['input_ids']
token_type_ids = inputs['token_type_ids']
attention = modelx(input_ids, token_type_ids=token_type_ids)[-1]
#sentence_b_start = token_type_ids[0].tolist().index(1)
input_id_list = input_ids[0].tolist() # Batch index 0
tokens = tokenizer.convert_ids_to_tokens(input_id_list) 
attention_unfreeze=attention
model_view(attention,tokens)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-9a09020f82314ad4bd4e2d2dc9ed99f6" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %%
# Load model and retrieve attention weights
from transformers import BertTokenizer, BertForSequenceClassification
from bertviz import head_view, model_view
from transformers import BertTokenizer, BertModel
modelx = modelx.to('cpu')
model_version = 'bert-base-uncased'

#model = BertForSequenceClassification.from_pretrained(model_version, output_attentions=True)
#modelx = modelx.from_pretrained(model_version, output_attentions=True)
tokenizer = BertTokenizer.from_pretrained(model_version)
sentence_a = "i like you to check and confirm what i said please."
sentence_b = "check and confirm my last question please."
inputs = tokenizer.encode_plus(sentence_a, return_tensors='pt')
input_ids = inputs['input_ids']
token_type_ids = inputs['token_type_ids']
attention = modelx(input_ids, token_type_ids=token_type_ids)[-1]
#sentence_b_start = token_type_ids[0].tolist().index(1)
input_id_list = input_ids[0].tolist() # Batch index 0
tokens = tokenizer.convert_ids_to_tokens(input_id_list) 
attention_unfreeze=attention
model_view(attention,tokens)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-70411d3eb33f42feb714c5d0b0a62105" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>
